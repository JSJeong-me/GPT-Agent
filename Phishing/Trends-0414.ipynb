# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/GPT-Agent/blob/main/Phishing/Trends-0414.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

# Google Colab 환경에서 실행 중인지 확인
if 'google.colab' in sys.modules:
    # debconf를 Noninteractive 모드로 설정
    # !echo 'debconf debconf/frontend select Noninteractive' | \
    debconf-set-selections

    # fonts-nanum 패키지를 설치
    # !sudo apt-get -qq -y install fonts-nanum

    # Matplotlib의 폰트 매니저 가져오기
    import matplotlib.font_manager as fm

    # 나눔 폰트의 시스템 경로 찾기
    font_files = fm.findSystemFonts(fontpaths=['/usr/share/fonts/truetype/nanum'])

    # 찾은 각 나눔 폰트를 Matplotlib 폰트 매니저에 추가
    for fpath in font_files:
        fm.fontManager.addfont(fpath)
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 126315 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20200506-1_all.deb ...
# Unpacking fonts-nanum (20200506-1) ...
# Setting up fonts-nanum (20200506-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 한글 폰트 설정 (예: 나눔고딕)
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 정의: 각 범주는 "전체" 또는 "1월~7월" 기간 구분 추가
categories = ["2019 전체", "2023 전체", "2023 (1월~7월)", "2024 (1월~7월)"]

# 피해금액 (단위: 억 원)
damage_amount = [6398, 4472, 2427, 3909]

# 피해건수 (건수 수치: 천 단위 구분 없이 정수)
damage_cases = [37667, 18902, 1741, 11734]

# x축 위치 설정
x = np.arange(len(categories))

# 그래프 그리기: 2행 1열 서브플롯 생성
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 8))

# 피해금액 그래프
ax1.bar(x, damage_amount, color='cornflowerblue')
ax1.set_title("연도별 피해금액 (단위: 억 원)")
ax1.set_xticks(x)
ax1.set_xticklabels(categories, rotation=45)
ax1.set_ylabel("피해금액 (억 원)")
# 막대 위에 값 표시
for idx, value in enumerate(damage_amount):
    ax1.text(x[idx], value + 50, str(value), ha='center', va='bottom', fontsize=9)

# 피해건수 그래프
ax2.bar(x, damage_cases, color='seagreen')
ax2.set_title("연도별 피해건수")
ax2.set_xticks(x)
ax2.set_xticklabels(categories, rotation=45)
ax2.set_ylabel("피해건수")
# 막대 위에 값 표시
for idx, value in enumerate(damage_cases):
    ax2.text(x[idx], value + 200, str(value), ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 정의: 각 범주는 "전체" 또는 "1월~7월" 기간 구분 추가
categories = ["2019 전체", "2023 전체", "2023 (1월~7월)", "2024 (1월~7월)"]

# 피해금액 (단위: 억 원)
damage_amount = [6398, 4472, 2427, 3909]

# 피해건수
damage_cases = [37667, 18902, 1741, 11734]

# x축 위치 설정
x = np.arange(len(categories))
width = 0.5 # 막대 폭을 줄였습니다.

# 그래프 그리기: 2행 1열 서브플롯 생성
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(5, 7))

# 피해금액 그래프
ax1.bar(x, damage_amount, width=width, color='cornflowerblue')
ax1.set_title("연도별 피해금액 (단위: 억 원)")
ax1.set_xticks(x)
ax1.set_xticklabels(categories, rotation=45)
ax1.set_ylabel("피해금액 (억 원)")
# 막대 위에 값 표시
for idx, value in enumerate(damage_amount):
    ax1.text(x[idx], value + 50, str(value), ha='center', va='bottom', fontsize=9)

# 피해건수 그래프
ax2.bar(x, damage_cases, width=width, color='seagreen')
ax2.set_title("연도별 피해건수")
ax2.set_xticks(x)
ax2.set_xticklabels(categories, rotation=45)
ax2.set_ylabel("피해건수")
# 막대 위에 값 표시
for idx, value in enumerate(damage_cases):
    ax2.text(x[idx], value + 200, str(value), ha='center', va='bottom', fontsize=9)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 데이터 정의
years = ["2019", "2020", "2021"]
damage_per_case = [1699, 2210, 2500]  # 단위: 만원

# x축 위치 설정 및 막대 폭 설정
x = np.arange(len(years))
bar_width = 0.3

# 그래프 생성
plt.figure(figsize=(5, 4))
bars = plt.bar(x, damage_per_case, width=bar_width, color='skyblue')

# 각 막대 위에 값 표시
for idx, value in enumerate(damage_per_case):
    plt.text(x[idx], value + 20, str(value), ha='center', va='bottom')

# 그래프 라벨 및 제목 설정
plt.xticks(x, years)
plt.xlabel("연도")
plt.ylabel("1건당 피해금액 (만원)")
plt.title("연도별 1건당 피해금액 (만원)")

plt.tight_layout()
plt.show()
